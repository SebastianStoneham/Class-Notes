# %%
import pandas as pd
import random 
toy_database = pd.DataFrame({"Security":['3M','TLSA','APPL'],
             "URL":['blahblah.com','wikisomething.com','wiki.com']})

# %%
for Security in toy_database['Security']:
    #print(Security)
    
    new_risk_var1 = random.randint(0,10)
    new_risk_var2 = random.randint(0,10)
    
    risk_factor1.append(new_risk_var1)
    
    risk_factor2.append(new_risk_var2)
toy_database

# %%
for index, rows in toy_database.itterrows():
    #print(index)
    print(row['Security'])
    #print('---------')
    #open 10k
    #here
    
    new_risk_var1 = random.randint(0,10)
    new_risk_var2 = random.randint(0,10)
    
    #put into database
    toy_database.at[index,'risk1'] = new_risk_var1
    toy_database.at[index,'risk2'] = new_risk_var2
    
toy_database
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-eda2dbec7b14> in <module>
# ----> 1 for index, rows in toy_database.itterrows():
#       2     #print(index)
#       3     print(row['Security'])
#       4     #print('---------')
#       5     #open 10k
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'itterrows'

# %% [markdown]
# #Measuring which risks tesla faces
# Brainstorm them :
#     - supply chain risk
#     - computer chips
#     - changes to tax policy
#     - price of alternatives (ICE, gas/oil)
#     - business cycle risk (inome of customers, preference changes)
#     - environmental regulation

# %%
# opening a 10k
fname = "10k_files/sec-edgar-filings/TSLA/10-K/0001564590-20-004475/filing-details.html"


with open (fname, encoding="utf-8") as report_file:
    html = report_file.read()

# %%
html[:100000]
# Out:
# '<?xml version="1.0" encoding="utf-8"?><!-- DFIN ActiveDisclosure(SM) Inline XBRL Document - http://www.dfinsolutions.com/ --><!-- Creation Date      : 2020-02-13T10:20:23.3895073+00:00 --><!-- Version            : 5.0.1.321 --><!-- Package ID         : 323b37309d3e4cdb824ea7eabcb9d5e2 --><!-- Copyright (c) 2020 Donnelley Financial Solutions, Inc. All Rights Reserved. --><html xmlns="http://www.w3.org/1999/xhtml" xmlns:country="http://xbrl.sec.gov/country/2017-01-31" xmlns:currency="http://xbrl.sec.gov/currency/2019-01-31" xmlns:dei="http://xbrl.sec.gov/dei/2019-01-31" xmlns:exch="http://xbrl.sec.gov/exch/2019-01-31" xmlns:invest="http://xbrl.sec.gov/invest/2013-01-31" xmlns:iso4217="http://www.xbrl.org/2003/iso4217" xmlns:ix="http://www.xbrl.org/2013/inlineXBRL" xmlns:ixt="http://www.xbrl.org/inlineXBRL/transformation/2015-02-26" xmlns:ixt-sec="http://www.sec.gov/inlineXBRL/transformation/2015-08-31" xmlns:link="http://www.xbrl.org/2003/linkbase" xmlns:naics="http://xbrl.sec.gov/naics/2017-01-31" xmlns:nonnum="http://www.xbrl.org/dtr/type/non-numeric" xmlns:num="http://www.xbrl.org/dtr/type/numeric" xmlns:sic="http://xbrl.sec.gov/sic/2011-01-31" xmlns:srt="http://fasb.org/srt/2019-01-31" xmlns:srt-types="http://fasb.org/srt-types/2019-01-31" xmlns:stpr="http://xbrl.sec.gov/stpr/2018-01-31" xmlns:tsla="http://www.teslamotors.com/20191231" xmlns:us-gaap="http://fasb.org/us-gaap/2019-01-31" xmlns:us-types="http://fasb.org/us-types/2019-01-31" xmlns:utr="http://www.xbrl.org/2009/utr" xmlns:xbrldi="http://xbrl.org/2006/xbrldi" xmlns:xbrli="http://www.xbrl.org/2003/instance" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n<head>\n<meta content="text/html" http-equiv="Content-Type"/>\n<title>\ntsla-10k_20191231.htm\n</title>\n</head>\n<!-- NG Converter v5.0.2.38 -->\n<body><div style="display:none">\n<ix:header>\n<ix:hidden>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000001" name="dei:AmendmentFlag">false</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000003" name="dei:DocumentFiscalYearFocus">2019</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000004" name="dei:DocumentFiscalPeriodFocus">FY</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000009" name="dei:EntityCentralIndexKey">0001318605</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000010" name="dei:CurrentFiscalYearEndDate">--12-31</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_20190101_20191231" id="F_000015" name="dei:EntityFilerCategory">Large Accelerated Filer</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_srtRangeAxis_srtMinimumMember_us-gaapPropertyPlantAndEquipmentByTypeAxis_us-gaapSoftwareAndSoftwareDevelopmentCostsMember_20190101_20191231" id="F_000798" name="us-gaap:FiniteLivedIntangibleAssetUsefulLife">P3Y</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_srtRangeAxis_srtMaximumMember_us-gaapPropertyPlantAndEquipmentByTypeAxis_us-gaapSoftwareAndSoftwareDevelopmentCostsMember_20190101_20191231" id="F_000799" name="us-gaap:FiniteLivedIntangibleAssetUsefulLife">P10Y</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_us-gaapDebtInstrumentAxis_tslaFivePointThreeZeroPercentSeniorNotesDueTwentyTwentyFiveMember_us-gaapLongtermDebtTypeAxis_tslaRecourseDebtMember_20190101_20191231" id="F_000980" name="us-gaap:DebtInstrumentMaturityDate">2025-08-31</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_us-gaapDebtInstrumentAxis_tslaFivePointThreeZeroPercentSeniorNotesDueTwentyTwentyFiveMember_us-gaapLongtermDebtTypeAxis_tslaRecourseDebtMember_20180101_20181231" id="F_000981" name="us-gaap:DebtInstrumentMaturityDate">2025-08-31</ix:nonnumeric>\n<ix:nonnumeric contextref="C_0001318605_us-gaapDebtInstrumentAxis_tslaOnePointTwoFivePercentConvertibleSeniorNoteDueInTwentyTwentyOneMember_us-gaapLongtermDebtTypeAxis_tslaRecourseDebtMember_201 ...

# %%
#practice our searches
from near_regex import NEAR_regex

# %%
import re

# %%
test  = 'This is a partial string another break with words'
words = ['partial','with']
rgx   = NEAR_regex(words)

# %%
print(len(re.findall(rgx,test)))
